# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
ref = 3.2e-5

# %%
colors = [
    '#e66101',
    '#fdb863',
    '#b2abd2',
    '#5e3c99'
]

# %%
def evals_error(data):
    estimates = np.array(data['exceedance_estimate'])
    error = mean_squared_error(np.log(ref) * np.ones(len(estimates)), np.log(estimates))
    evals = np.array(data['performance_evaluation']).mean()
    return evals, error

def evals_sum(data):
    avg_sum = data['total_maxima'].mean()
    evals = np.array(data['performance_evaluation']).mean()
    return evals, avg_sum

# %%
os.chdir('../numerical_examples/data')

with open("bre_sus_dim_2.json", 'r') as file:
    loaded_results = json.load(file)
bre_sus_dim_2 = pd.DataFrame(loaded_results)


with open("bre_bss_dim_2.json", 'r') as file:
    loaded_results = json.load(file)
bre_bss_dim_2 = pd.DataFrame(loaded_results)


with open("bre_bss_dim_50.json", 'r') as file:
    loaded_results = json.load(file)
bre_bss_dim_50 = pd.DataFrame(loaded_results)

with open("him_sus_dim_2.json", 'r') as file:
    loaded_results = json.load(file)
him_sus_dim_2 = pd.DataFrame(loaded_results)
him_sus_dim_2['total_maxima']= him_sus_dim_2['region_indicator'].apply(sum)


with open("him_bss_dim_2.json", 'r') as file:
    loaded_results = json.load(file)
him_bss_dim_2 = pd.DataFrame(loaded_results)
him_bss_dim_2['total_maxima']= him_bss_dim_2['region_indicator'].apply(sum)


with open("him_bss_dim_50.json", 'r') as file:
    loaded_results = json.load(file)
him_bss_dim_50 = pd.DataFrame(loaded_results)
him_bss_dim_50['total_maxima']= him_bss_dim_50['region_indicator'].apply(sum)


os.chdir('../../figures')

# %%
bre_sus_dim_2_points = []
for size in [100,250,500,750,1000,1250,1500,2000,3000]:
    bre_sus_dim_2_points.append(evals_error(bre_sus_dim_2[bre_sus_dim_2['size']==size]))
    
bre_bss_dim_2_budg_100_points = []
bre_bss_dim_2_budg_100 = bre_bss_dim_2[bre_bss_dim_2['graph_budget'] == 100]
for size in [500,1000,1500]:
    bre_bss_dim_2_budg_100_points.append(evals_error(bre_bss_dim_2_budg_100[bre_bss_dim_2_budg_100['size']==size]))
    
bre_bss_dim_2_budg_500_points = []
bre_bss_dim_2_budg_500 = bre_bss_dim_2[bre_bss_dim_2['graph_budget'] == 500]
for size in [500,1000,1500]:
    bre_bss_dim_2_budg_500_points.append(evals_error(bre_bss_dim_2_budg_500[bre_bss_dim_2_budg_500['size']==size]))
    
bre_bss_dim_2_budg_1000_points = []
bre_bss_dim_2_budg_1000 = bre_bss_dim_2[bre_bss_dim_2['graph_budget'] == 1000]
for size in [500,1000,1500]:
    bre_bss_dim_2_budg_1000_points.append(evals_error(bre_bss_dim_2_budg_1000[bre_bss_dim_2_budg_1000['size']==size]))
     
bre_bss_dim_50_budg_100_points = []
bre_bss_dim_50_budg_100 = bre_bss_dim_50[bre_bss_dim_50['graph_budget'] == 100]
for size in [500,1000,1500]:
    bre_bss_dim_50_budg_100_points.append(evals_error(bre_bss_dim_50_budg_100[bre_bss_dim_50_budg_100['size']==size]))
    
bre_bss_dim_50_budg_500_points = []
bre_bss_dim_50_budg_500 = bre_bss_dim_50[bre_bss_dim_50['graph_budget'] == 500]
for size in [500,1000,1500]:
    bre_bss_dim_50_budg_500_points.append(evals_error(bre_bss_dim_50_budg_500[bre_bss_dim_50_budg_500['size']==size]))
    
bre_bss_dim_50_budg_1000_points = []
bre_bss_dim_50_budg_1000 = bre_bss_dim_50[bre_bss_dim_50['graph_budget'] == 1000]
for size in [500,1000,1500]:
    bre_bss_dim_50_budg_1000_points.append(evals_error(bre_bss_dim_50_budg_1000[bre_bss_dim_50_budg_1000['size']==size]))
    
him_sus_dim_2_points = []
for size in [100,500,1000,1500,2000]:
    him_sus_dim_2_points.append(evals_sum(him_sus_dim_2[him_sus_dim_2['size']==size]))
    
him_bss_dim_2_budg_100_points = []
him_bss_dim_2_budg_100 = him_bss_dim_2[him_bss_dim_2['graph_budget'] == 100]
for size in [100,500,1000]:
    him_bss_dim_2_budg_100_points.append(evals_sum(him_bss_dim_2_budg_100[him_bss_dim_2_budg_100['size']==size]))
    
him_bss_dim_2_budg_250_points = []
him_bss_dim_2_budg_250 = him_bss_dim_2[him_bss_dim_2['graph_budget'] == 250]
for size in [100,500,1000]:
    him_bss_dim_2_budg_250_points.append(evals_sum(him_bss_dim_2_budg_250[him_bss_dim_2_budg_250['size']==size]))
    
    
him_bss_dim_2_budg_500_points = []
him_bss_dim_2_budg_500 = him_bss_dim_2[him_bss_dim_2['graph_budget'] == 500]
for size in [100,500,1000]:
    him_bss_dim_2_budg_500_points.append(evals_sum(him_bss_dim_2_budg_500[him_bss_dim_2_budg_500['size']==size]))
    
    
him_bss_dim_50_budg_100_points = []
him_bss_dim_50_budg_100 = him_bss_dim_50[him_bss_dim_50['graph_budget'] == 100]
for size in [100,500,1000]:
    him_bss_dim_50_budg_100_points.append(evals_sum(him_bss_dim_50_budg_100[him_bss_dim_50_budg_100['size']==size]))
    
him_bss_dim_50_budg_250_points = []
him_bss_dim_50_budg_250 = him_bss_dim_50[him_bss_dim_50['graph_budget'] == 250]
for size in [100,500,1000]:
    him_bss_dim_50_budg_250_points.append(evals_sum(him_bss_dim_50_budg_250[him_bss_dim_50_budg_250['size']==size]))
    
him_bss_dim_50_budg_500_points = []
him_bss_dim_50_budg_500 = him_bss_dim_50[him_bss_dim_50['graph_budget'] == 500]
for size in [100,500,1000]:
    him_bss_dim_50_budg_500_points.append(evals_sum(him_bss_dim_50_budg_500[him_bss_dim_50_budg_500['size']==size]))

# %%
plt.style.use('ggplot')
cm_width = 19
cm_to_inch = 0.393701
figWidth = cm_width * cm_to_inch
fig_aspect_ratio = 7./10.
figHeight = figWidth * fig_aspect_ratio 
plt.figure(figsize=(figWidth, figHeight), dpi=300)

plotter = np.array(bre_sus_dim_2_points)[2:].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[3],
         label='SuS')

plotter = np.array(bre_bss_dim_2_budg_100_points)[:].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 100')

plotter = np.array(bre_bss_dim_2_budg_500_points)[:].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 500') 

plotter = np.array(bre_bss_dim_2_budg_1000_points)[:].T
plt.plot(plotter[0],
         plotter[1], 
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 1000')


plt.text(2.5*10**(3),19.7,'SuS')
plt.text(2.8*10**(3),8.5,'100')
plt.text(5*10**(3),6.2,'500')
plt.text(7.7*10**(3),5.4,'1000')



plt.xlabel('Performance Evaluations')
plt.ylabel('MSLE')
plt.ticklabel_format(axis='x', style='sci', scilimits=(3,3), useMathText=True)
plt.savefig('linear_sus_bss_dim_2.pdf',bbox_inches='tight')


plt.show()

# %%
plt.style.use('ggplot')
cm_width = 19
cm_to_inch = 0.393701
figWidth = cm_width * cm_to_inch
fig_aspect_ratio = 7./10.
figHeight = figWidth * fig_aspect_ratio 
plt.figure(figsize=(figWidth, figHeight), dpi=300)

plotter = np.array(bre_sus_dim_2_points)[2:].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[3],
         label='SuS')

plotter = np.array(bre_bss_dim_50_budg_100_points)[:].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 100')

plotter = np.array(bre_bss_dim_50_budg_500_points)[:].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 500') 

plotter = np.array(bre_bss_dim_50_budg_1000_points)[:].T
plt.plot(plotter[0],
         plotter[1], 
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 1000')


plt.text(2.5*10**(3),20,'SuS')
plt.text(3*10**(3),17.8,'100')
plt.text(5.8*10**(3),11.5,'500')
plt.text(8.8*10**(3),7.8,'1000')



plt.xlabel('Performance Evaluations')
plt.ylabel('MSLE')
plt.ticklabel_format(axis='x', style='sci', scilimits=(3,3), useMathText=True)
plt.savefig('linear_sus_bss_dim_50.pdf',bbox_inches='tight')


plt.show()

# %%
plt.style.use('ggplot')
cm_width = 19
cm_to_inch = 0.393701
figWidth = cm_width * cm_to_inch
fig_aspect_ratio = 7./10.
figHeight = figWidth * fig_aspect_ratio 
plt.figure(figsize=(figWidth, figHeight), dpi=300)

plotter = np.array(him_sus_dim_2_points)[:-1].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[3],
         label='SuS')

plotter = np.array(him_bss_dim_2_budg_100_points)[:].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 100')

plotter = np.array(him_bss_dim_2_budg_250_points)[:].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 500') 

plotter = np.array(him_bss_dim_2_budg_500_points)[:].T
plt.plot(plotter[0],
         plotter[1], 
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 1000')


plt.text(1.5*10**(3),1.28,'SuS')
plt.text(0.45*10**(3),1.87,'100')
plt.text(1.3*10**(3),1.6,'250')
plt.text(13.9*10**(3),2.95,'500')



plt.xlabel('Performance Evaluations')
plt.ylabel('Maxima Found')
plt.ticklabel_format(axis='x', style='sci', scilimits=(3,3), useMathText=True)
plt.savefig('himmel_sus_bss_dim_2.pdf',bbox_inches='tight')


plt.show()

# %%
plt.style.use('ggplot')
cm_width = 19
cm_to_inch = 0.393701
figWidth = cm_width * cm_to_inch
fig_aspect_ratio = 7./10.
figHeight = figWidth * fig_aspect_ratio 
plt.figure(figsize=(figWidth, figHeight), dpi=300)

plotter = np.array(him_sus_dim_2_points)[:-1].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[3],
         label='SuS')

plotter = np.array(him_bss_dim_50_budg_100_points)[:].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 100')

plotter = np.array(him_bss_dim_50_budg_250_points)[:].T
plt.plot(plotter[0],
         plotter[1],
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 500') 

plotter = np.array(him_bss_dim_50_budg_500_points)[:].T
plt.plot(plotter[0],
         plotter[1], 
         marker='o',
         color=colors[0],
         linestyle='solid',
         label='BSuS - Budget 1000')


plt.text(1.5*10**(3),1.28,'SuS')
plt.text(9.6*10**(3),2.78,'100')
plt.text(13*10**(3),2.85,'250')
plt.text(16.5*10**(3),2.82,'500')



plt.xlabel('Performance Evaluations')
plt.ylabel('Maxima Found')
plt.ticklabel_format(axis='x', style='sci', scilimits=(3,3), useMathText=True)
plt.savefig('himmel_sus_bss_dim_50.pdf',bbox_inches='tight')


plt.show()
